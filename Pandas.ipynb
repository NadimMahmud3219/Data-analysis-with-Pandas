# %% [markdown]
# <a href="https://colab.research.google.com/github/NadimMahmud3219/Data-analysis-with-Pandas/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd #first of all we have to import pandas library

# %%
df = pd.read_csv('/content/tested.csv') #create dataframe and load the csv file

# %%
df.shape #by using this command we can able to see how many rows and columns in our dataset
# Out:
# (418, 12)

# %%
df.head() #by using this command we van able to see first 5 row of our dataset
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df.tail()#by using this command we van able to see last 5 row of our dataset
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 413         1305         0       3            Spector, Mr. Woolf    male
# 414         1306         1       1  Oliva y Ocana, Dona. Fermina  female
# 415         1307         0       3  Saether, Mr. Simon Sivertsen    male
# 416         1308         0       3           Ware, Mr. Frederick    male
# 417         1309         0       3      Peter, Master. Michael J    male
#
#       Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 413   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  39.0      0      0            PC 17758  108.9000  C105        C
# 415  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416   NaN      0      0              359309    8.0500   NaN        S
# 417   NaN      1      1                2668   22.3583   NaN        C

# %%
df.head(10) #we can define the value how many row we want to see from our dataset
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
# 5          897         0       3
# 6          898         1       3
# 7          899         0       2
# 8          900         1       3
# 9          901         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# 5                    Svensson, Mr. Johan Cervin    male  14.0      0      0
# ...

# %%
df #By using df we can able to see first & last 5 row of our dataset
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df.info() #by using this command we can able to see the whole information about our dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
df.describe() #we can able to see the statistical information of our dataset
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
df['Name'] #we can access a particular columns
# Out:
# 0                                  Kelly, Mr. James
# 1                  Wilkes, Mrs. James (Ellen Needs)
# 2                         Myles, Mr. Thomas Francis
# 3                                  Wirz, Mr. Albert
# 4      Hirvonen, Mrs. Alexander (Helga E Lindqvist)
#                            ...
# 413                              Spector, Mr. Woolf
# 414                    Oliva y Ocana, Dona. Fermina
# 415                    Saether, Mr. Simon Sivertsen
# 416                             Ware, Mr. Frederick
# 417                        Peter, Master. Michael J
# Name: Name, Length: 418, dtype: object

# %%
df.Name # we can also access a particular attribute by using this
# Out:
# 0                                  Kelly, Mr. James
# 1                  Wilkes, Mrs. James (Ellen Needs)
# 2                         Myles, Mr. Thomas Francis
# 3                                  Wirz, Mr. Albert
# 4      Hirvonen, Mrs. Alexander (Helga E Lindqvist)
#                            ...
# 413                              Spector, Mr. Woolf
# 414                    Oliva y Ocana, Dona. Fermina
# 415                    Saether, Mr. Simon Sivertsen
# 416                             Ware, Mr. Frederick
# 417                        Peter, Master. Michael J
# Name: Name, Length: 418, dtype: object

# %%
type(df['Name']) #type of data
# Out:
# pandas.core.series.Series

# %%
df[['Name','Sex']] # we can acees multiple attribute at a time
# Out:
#                                              Name     Sex
# 0                                Kelly, Mr. James    male
# 1                Wilkes, Mrs. James (Ellen Needs)  female
# 2                       Myles, Mr. Thomas Francis    male
# 3                                Wirz, Mr. Albert    male
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# ..                                            ...     ...
# 413                            Spector, Mr. Woolf    male
# 414                  Oliva y Ocana, Dona. Fermina  female
# 415                  Saether, Mr. Simon Sivertsen    male
# 416                           Ware, Mr. Frederick    male
# 417                      Peter, Master. Michael J    male
#
# [418 rows x 2 columns]

# %%
df.columns #we can only print the columns name of our dataset
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.iloc[0] # we can access rows also
# Out:
# PassengerId                 892
# Survived                      0
# Pclass                        3
# Name           Kelly, Mr. James
# Sex                        male
# Age                        34.5
# SibSp                         0
# Parch                         0
# Ticket                   330911
# Fare                     7.8292
# Cabin                       NaN
# Embarked                      Q
# Name: 0, dtype: object

# %%
df.loc[[0,1,2],['Name','Sex','Age']] #we can access a particular portion of a dataset
# Out:
#                                Name     Sex   Age
# 0                  Kelly, Mr. James    male  34.5
# 1  Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 2         Myles, Mr. Thomas Francis    male  62.0

# %%
df['Sex'].value_counts() #we can count the value
# Out:
# male      266
# female    152
# Name: Sex, dtype: int64

# %% [markdown]
# # Filtaring

# %%
filt = (df['Sex']=='male')
df[filt].head() #we can filter our data
# Out:
#    PassengerId  Survived  Pclass                          Name   Sex   Age  \
# 0          892         0       3              Kelly, Mr. James  male  34.5
# 2          894         0       2     Myles, Mr. Thomas Francis  male  62.0
# 3          895         0       3              Wirz, Mr. Albert  male  27.0
# 5          897         0       3    Svensson, Mr. Johan Cervin  male  14.0
# 7          899         0       2  Caldwell, Mr. Albert Francis  male  26.0
#
#    SibSp  Parch  Ticket     Fare Cabin Embarked
# 0      0      0  330911   7.8292   NaN        Q
# 2      0      0  240276   9.6875   NaN        Q
# 3      0      0  315154   8.6625   NaN        S
# 5      0      0    7538   9.2250   NaN        S
# 7      1      1  248738  29.0000   NaN        S

# %%
df.loc[filt, 'Name']
# Out:
# 0                  Kelly, Mr. James
# 2         Myles, Mr. Thomas Francis
# 3                  Wirz, Mr. Albert
# 5        Svensson, Mr. Johan Cervin
# 7      Caldwell, Mr. Albert Francis
#                    ...
# 407      Widener, Mr. George Dunton
# 413              Spector, Mr. Woolf
# 415    Saether, Mr. Simon Sivertsen
# 416             Ware, Mr. Frederick
# 417        Peter, Master. Michael J
# Name: Name, Length: 266, dtype: object

# %%
filt=(df['Sex']=='male') & (df['Embarked']=="S") & (df['Age']==27)
df[filt]
# Out:
#      PassengerId  Survived  Pclass                       Name   Sex   Age  \
# 3            895         0       3           Wirz, Mr. Albert  male  27.0
# 101          993         0       2         Weisz, Mr. Leopold  male  27.0
# 318         1210         0       3  Jonsson, Mr. Nils Hilding  male  27.0
# 334         1226         0       3              Cor, Mr. Ivan  male  27.0
# 363         1255         0       3          Strilic, Mr. Ivan  male  27.0
#
#      SibSp  Parch  Ticket     Fare Cabin Embarked
# 3        0      0  315154   8.6625   NaN        S
# 101      1      0  228414  26.0000   NaN        S
# 318      0      0  350408   7.8542   NaN        S
# 334      0      0  349229   7.8958   NaN        S
# 363      0      0  315083   8.6625   NaN        S

# %%
age = (df['Age']>=25)
df[age].head()
# Out:
#    PassengerId  Survived  Pclass                              Name     Sex  \
# 0          892         0       3                  Kelly, Mr. James    male
# 1          893         1       3  Wilkes, Mrs. James (Ellen Needs)  female
# 2          894         0       2         Myles, Mr. Thomas Francis    male
# 3          895         0       3                  Wirz, Mr. Albert    male
# 6          898         1       3              Connolly, Miss. Kate  female
#
#     Age  SibSp  Parch  Ticket    Fare Cabin Embarked
# 0  34.5      0      0  330911  7.8292   NaN        Q
# 1  47.0      1      0  363272  7.0000   NaN        S
# 2  62.0      0      0  240276  9.6875   NaN        Q
# 3  27.0      0      0  315154  8.6625   NaN        S
# 6  30.0      0      0  330972  7.6292   NaN        Q

# %%
age = (df['Age']<=25)
df[age].head()
# Out:
#     PassengerId  Survived  Pclass  \
# 4           896         1       3
# 5           897         0       3
# 8           900         1       3
# 9           901         0       3
# 12          904         1       1
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# 5                      Svensson, Mr. Johan Cervin    male  14.0      0      0
# 8       Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female  18.0      0      0
# 9                         Davies, Mr. John Samuel    male  21.0      2      0
# 12  Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1      0
#
#        Ticket     Fare Cabin Embarked
# 4     3101298  12.2875   NaN        S
# 5        7538   9.2250   NaN        S
# 8        2657   7.2292   NaN        C
# 9   A/4 48871  24.1500   NaN        S
# 12      21228  82.2667   B45        S

# %%
df[(df['Age']<=20) & (df['Sex']=='female')].head()
# Out:
#     PassengerId  Survived  Pclass                                       Name  \
# 8           900         1       3  Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 52          944         1       2              Hocking, Miss. Ellen Nellie""
# 66          958         1       3                    Burns, Miss. Mary Delia
# 87          979         1       3                 Badman, Miss. Emily Louisa
# 98          990         1       3               Braf, Miss. Elin Ester Maria
#
#        Sex   Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# 8   female  18.0      0      0       2657   7.2292   NaN        C
# 52  female  20.0      2      1      29105  23.0000   NaN        S
# 66  female  18.0      0      0     330963   7.8792   NaN        Q
# 87  female  18.0      0      0  A/4 31416   8.0500   NaN        S
# 98  female  20.0      0      0     347471   7.8542   NaN        S

# %%
df.rename(columns={'Name':'Passenger_name'},inplace = True) #we can rename the columns name

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                    Passenger_name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df['New_column'] = df['Passenger_name']+ ' ' + df['Cabin'] # we can add new columns

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                  Passenger_name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked New_column
# 0   330911   7.8292   NaN        Q        NaN
# 1   363272   7.0000   NaN        S        NaN
# 2   240276   9.6875   NaN        Q        NaN
# 3   315154   8.6625   NaN        S        NaN
# 4  3101298  12.2875   NaN        S        NaN

# %%
df.drop(columns=['New_column'],axis = 1,inplace = True) #we can also drop columns

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                  Passenger_name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %% [markdown]
# #Null value handling

# %%
df.isnull().sum()
# Out:
# PassengerId         0
# Survived            0
# Pclass              0
# Passenger_name      0
# Sex                 0
# Age                86
# SibSp               0
# Parch               0
# Ticket              0
# Fare                1
# Cabin             327
# Embarked            0
# dtype: int64

# %%
df['Age'].mean()
# Out:
# 30.272590361445783

# %%
b = df.fillna(df['Age'].mean(),inplace = True)

# %%
df.isnull().sum()
# Out:
# PassengerId       0
# Survived          0
# Pclass            0
# Passenger_name    0
# Sex               0
# Age               0
# SibSp             0
# Parch             0
# Ticket            0
# Fare              0
# Cabin             0
# Embarked          0
# dtype: int64

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                  Passenger_name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare     Cabin Embarked
# 0   330911   7.8292  30.27259        Q
# 1   363272   7.0000  30.27259        S
# 2   240276   9.6875  30.27259        Q
# 3   315154   8.6625  30.27259        S
# 4  3101298  12.2875  30.27259        S

# %% [markdown]
# #finding the maximum age

# %%
df['Age'].max()
# Out:
# 76.0

# %% [markdown]
# Finding the all value of Abrahim, Mrs. Joseph (Sophie Halaut Easu)

# %%
df[df['Passenger_name']=='Abrahim, Mrs. Joseph (Sophie Halaut Easu)']
# Out:
#    PassengerId  Survived  Pclass                             Passenger_name  \
# 8          900         1       3  Abrahim, Mrs. Joseph (Sophie Halaut Easu)
#
#       Sex   Age  SibSp  Parch Ticket    Fare     Cabin Embarked
# 8  female  18.0      0      0   2657  7.2292  30.27259        C

# %% [markdown]
# finding the age of Abrahim, Mrs. Joseph (Sophie Halaut Easu)

# %%
df[df['Passenger_name']=='Abrahim, Mrs. Joseph (Sophie Halaut Easu)']['Age']
# Out:
# 8    18.0
# Name: Age, dtype: float64

# %% [markdown]
# finding the ticket number of Abrahim, Mrs. Joseph (Sophie Halaut Easu)

# %%
df[df['Passenger_name']=='Abrahim, Mrs. Joseph (Sophie Halaut Easu)']['Ticket']
# Out:
# 8    2657
# Name: Ticket, dtype: object

# %% [markdown]
# find the all informayion of the oldest person of the ship

# %%
df[df['Age'] == df['Age'].max()]
# Out:
#     PassengerId  Survived  Pclass  \
# 96          988         1       1
#
#                                        Passenger_name     Sex   Age  SibSp  \
# 96  Cavendish, Mrs. Tyrell William (Julia Florence...  female  76.0      1
#
#     Parch Ticket   Fare Cabin Embarked
# 96      0  19877  78.85   C46        S

# %% [markdown]
# find the name of oldest person of the ship

# %%
df[df['Age'] == df['Age'].max()]['Passenger_name']
# Out:
# 96    Cavendish, Mrs. Tyrell William (Julia Florence...
# Name: Passenger_name, dtype: object

# %% [markdown]
# find the name of youngest  person of the ship

# %%
df[df['Age'] == df['Age'].min()]['Passenger_name']
# Out:
# 354    Dean, Miss. Elizabeth Gladys Millvina""
# Name: Passenger_name, dtype: object

# %% [markdown]
# find the information of youngest person

# %%
df[df['Age'] == df['Age'].min()]
# Out:
#      PassengerId  Survived  Pclass                           Passenger_name  \
# 354         1246         1       3  Dean, Miss. Elizabeth Gladys Millvina""
#
#         Sex   Age  SibSp  Parch     Ticket    Fare     Cabin Embarked
# 354  female  0.17      1      2  C.A. 2315  20.575  30.27259        S

# %%
df.groupby('Age').mean()
# Out:
#        PassengerId  Survived  Pclass     SibSp  Parch        Fare
# Age
# 0.17        1246.0  1.000000     3.0  1.000000    2.0   20.575000
# 0.33        1093.0  0.000000     3.0  0.000000    2.0   14.400000
# 0.75        1173.0  0.000000     3.0  1.000000    1.0   13.775000
# 0.83        1199.0  0.000000     3.0  0.000000    1.0    9.350000
# 0.92        1142.0  1.000000     2.0  1.000000    2.0   27.750000
# ...            ...       ...     ...       ...    ...         ...
# 62.00        894.0  0.000000     2.0  0.000000    0.0    9.687500
# 63.00        955.5  0.500000     1.5  1.000000    0.0  123.889600
# 64.00       1132.0  0.666667     1.0  0.666667    1.0   61.652767
# 67.00        973.0  0.000000     1.0  1.000000    0.0  221.779200
# 76.00        988.0  1.000000     1.0  1.000000    0.0   78.850000
#
# [80 rows x 6 columns]

# %% [markdown]
# find the unique value of cabin

# %%
df['Cabin'].nunique()
# Out:
# 77

# %% [markdown]
# find the most common cabin

# %%
df['Cabin'].value_counts().head(5)
# Out:
# 30.272590361445783    327
# B57 B59 B63 B66         3
# C89                     2
# C116                    2
# C80                     2
# Name: Cabin, dtype: int64
